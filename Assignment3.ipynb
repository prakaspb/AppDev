# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
from matplotlib.lines import Line2D
from matplotlib.text import Text

def draw_neural_network():
    fig, ax = plt.subplots(figsize=(12, 6))
    ax.set_title(
        "Neural Network Architecture for Credit Card Fraud Detection",
        fontsize=14,
        fontweight="bold"
    )

    # Define layers
    layers = {
        "Input Layer": [
            "TransactionAmount",
            "TransactionTime",
            "MerchantCategory",
            "CustomerAge",
            "AccountBalance",
            "NumberOfTransactionsToday"
        ],
        "Hidden Layer 1": ["H1", "H2", "H3", "H4", "H5"],
        "Hidden Layer 2": ["H6", "H7", "H8"],
        "Output Layer": ["Fraud (1) / Genuine (0)"]
    }

    # X positions of layers
    #x_positions = [0.1, 0.2, 0.5, 0.7]
    x_positions = [0.1, 0.4, 0.7, 0.9]

    y_center = 0.5

    all_layer_nodes = []

    # Draw nodes
    for (layer_name, nodes), x in zip(layers.items(), x_positions):
        y_positions = [y_center - i * 0.1 for i in range(len(nodes))]
        layer_nodes = []

        for node, y in zip(nodes, y_positions):
            circle = Circle((x, y), 0.03, fc="skyblue", ec="black")
            ax.add_patch(circle)
            ax.text(x, y - 0.05, node, ha="center", fontsize=8)
            layer_nodes.append((x, y))

        ax.text(x, y_positions[0] + 0.1, layer_name,
                ha="center", fontsize=10, fontweight="bold")

        all_layer_nodes.append(layer_nodes)

    # Draw connections
    for i in range(len(all_layer_nodes) - 1):
        for (x1, y1) in all_layer_nodes[i]:
            for (x2, y2) in all_layer_nodes[i + 1]:
                ax.plot([x1, x2], [y1, y2], color="gray", linewidth=0.6)

    ax.axis("off")
    plt.show()

# Draw the neural network
draw_neural_network()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

def draw_neural_network():
    #fig, ax = plt.subplots(figsize=(6, 3))
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.set_title(
        "Neural Network Architecture for Credit Card Fraud Detection",
        fontsize=14,
        fontweight="bold"
    )

    # Define layers
    layers = {
        "Input Layer": [
            "TransactionAmount",
            "TransactionTime",
            "MerchantCategory",
            "CustomerAge",
            "AccountBalance",
            "NumberOfTransactionsToday"
        ],
        "Hidden Layer 1": ["H1", "H2", "H3", "H4", "H5"],
        "Hidden Layer 2": ["H6", "H7", "H8"],
        "Output Layer": ["Fraud (1) / Genuine (0)"]
    }

    # X positions of layers
    #x_positions = [0.1, 0.2, 0.5, 0.7]
    x_positions = [0.1, 0.4, 0.7, 0.9]

    y_center = 0.5

    all_layer_nodes = []

    # Draw nodes
    for (layer_name, nodes), x in zip(layers.items(), x_positions):
        y_positions = [y_center - i * 0.1 for i in range(len(nodes))]
        layer_nodes = []

        for node, y in zip(nodes, y_positions):
            #circle = Circle((x, y), 0.03, fc="skyblue", ec="black")
            circle = Circle((x, y), 0.03, fc="green", ec="red")
            ax.add_patch(circle)
            ax.text(x, y - 0.05, node, ha="center", fontsize=8)
            layer_nodes.append((x, y))

        ax.text(x, y_positions[0] + 0.1, layer_name,
                ha="center", fontsize=10, fontweight="bold")

        all_layer_nodes.append(layer_nodes)

    # Draw connections
    for i in range(len(all_layer_nodes) - 1):
        for (x1, y1) in all_layer_nodes[i]:
            for (x2, y2) in all_layer_nodes[i + 1]:
                ax.plot([x1, x2], [y1, y2], color="gray", linewidth=0.6)

    ax.axis("off")
    plt.show()

# Draw the neural network
draw_neural_network()

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

def draw_neural_network():
    #fig, ax = plt.subplots(figsize=(6, 3))
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.set_title(
        "Neural Network Architecture for Credit Card Fraud Detection",
        fontsize=14,
        fontweight="bold"
    )

    # Define layers
    layers = {
        "Input Layer": [
            "TransactionAmount",
            "TransactionTime",
            "MerchantCategory",
            "CustomerAge",
            "AccountBalance",
            "NumberOfTransactionsToday"
        ],
        "Hidden Layer 1": ["H1", "H2", "H3", "H4", "H5"],
        "Hidden Layer 2": ["H6", "H7", "H8"],
        "Output Layer": ["Fraud (1) / Genuine (0)"]
    }

    # X positions of layers
    #x_positions = [0.1, 0.2, 0.5, 0.7]
    x_positions = [0.1, 0.4, 0.7, 0.9]

    y_center = 0.9

    all_layer_nodes = []

    # Draw nodes
    for (layer_name, nodes), x in zip(layers.items(), x_positions):
        y_positions = [y_center - i * 0.1 for i in range(len(nodes))]
        layer_nodes = []

        for node, y in zip(nodes, y_positions):
            #circle = Circle((x, y), 0.03, fc="skyblue", ec="black")
            circle = Circle((x, y), 0.03, fc="green", ec="red")
            ax.add_patch(circle)
            ax.text(x, y - 0.09, node, ha="center", fontsize=10)
            layer_nodes.append((x, y))

        ax.text(x, y_positions[0] + 0.1, layer_name,
                ha="center", fontsize=10, fontweight="bold")

        all_layer_nodes.append(layer_nodes)

    # Draw connections
    for i in range(len(all_layer_nodes) - 1):
        for (x1, y1) in all_layer_nodes[i]:
            for (x2, y2) in all_layer_nodes[i + 1]:
                ax.plot([x1, x2], [y1, y2], color="gray", linewidth=0.6)

    ax.axis("off")
    plt.show()

# Draw the neural network
draw_neural_network()
